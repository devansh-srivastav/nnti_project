# %% [markdown]
# # Task 2: Visualize hidden represenations of a model

# %%
import h5py

import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# TODO: your code goes here

# %%
import torch 
import h5py

import datasets
import numpy as np
import transformers
import random

# %%
MODEL_NAME = "facebook/xglm-564M"
DATASET_NAME = "facebook/flores"

# %%
LANGUAGES = [
    "eng_Latn",
    "spa_Latn",
    "deu_Latn",
    "arb_Arab",
    "tam_Taml",
    "quy_Latn"
]

# %%
data = {}
for lang in LANGUAGES:
    data[lang] = datasets.load_dataset("facebook/flores", lang, trust_remote_code=True)

# %%
len(data["eng_Latn"]["dev"])
# Out:
# 997

# %%
random_indexes = random.sample(range(len(data["eng_Latn"]["dev"])), 200)

# %%
extracted_sentences = {}
for lang in LANGUAGES:
    extracted_sentences[lang] = [data[lang]["dev"][i]["sentence"] for i in random_indexes]

# %%
extracted_sentences
# Out:
# {'eng_Latn': ['In his notes he used words which some parents considered coarse, and he reportedly used profanity in class.',
#   'Day hiking involves distances of less than a mile up to longer distances that can be covered in a single day.',
#   'The town lies immediately next to the falls, and they are the major attraction, but this popular tourist destination offers both adventure seekers and sightseers plenty of opportunities for a longer stay.',
#   "There is also no requirement that you obtain a local number from the community in which you live; you can obtain a satellite Internet connection in the wilds of Chicken, Alaska and select a number which claims you're in sunny Arizona.",
#   'Although its physical state may change, its chemical state remains the same.',
#   'This will ensure that your particular interests and/or constraints are matched with the ship most suitable to them.',
#   'Typical for the period, Kirby Muxloe Castle is more of a fortified house than a true castle.',
#   'The earliest known book in the world was written in Sanskrit. After the compilation of Upanishads, Sanskrit just faded due to hierarchy.',
#   'As of the night of August 9, the eye of Morakot was about seventy kilometres away from the Chinese province of Fujian.',
#   'Nadia, born on September 17, 2007, by Cesarean section at a maternity clinic in Aleisk, Russia, weighed in at a massive 17 pounds 1 ounce.',
#   'It has the same molecular structure whether it is a gas, liquid, or solid.',
#   'Many a stable, capable traveler has been overcome by the newness of developing world travel, where many little cultural adjustments can add up quickly.',
#   'As far as we know, there is only one planetary body that displays more dynamism than Titan, and its name is Earth," added Stofan.',
#   "China's GDP could be larger than the United States within two decades.",
#   'The White Sea–Baltic Canal connects the Arctic Ocean to the Baltic Sea, via Lake Onega, Lake Ladoga and Saint Petersburg, mostly by rivers and lakes.',
#   'Jardín de la Unión. This space was built as the atrium for a 17th-century convent, of which the Templo de San Diego is the sole surviving building.',
#   'With the same time zone as Hawaii, the islands are sometimes thought of as "Hawaii down under".',
#   'This contradicts earlier reports, which said that cancelling the runoff would have been against the constitution.',
#   'Nowadays air travel is only rarely booked directly through the airline without first searching and comparing prices.',
#   'This can be done in a normal car with careful planning but a 4x4 is highly advised and many locations are only accessible with a high wheel base 4x4.',
#   'Sikhs consider their faith to be a separate religion from Hinduism though they acknowledge its Hindu roots and traditions.',
#   'Jarque was practicing during pre-season training at Coverciano in Italy earlier in the day. He was staying in the team hotel ahead of a match planned for Sunday against Bolonia.',
#   'What is a cell? The word cell comes from the Latin word "cella", meaning "small room", and it was first coined by a microscopist observing the structure of cork.',
#   'He joined them in 1945 and stayed until 1958.',
#   'In the rainy season (November to March), the water volume will be higher and the Falls will be more dramatic.',
#   'The case was prosecuted in Virginia because it is the home to the leading internet service provider AOL, the company who instigated the charges.',
#   'Lodin also said officials decided to cancel the runoff in order to save Afghans the expense and security risk of another election.',
#   'Time is something that is all around us, and affects everything we do, yet is difficult to understand.',
#   'Until now, AOL has been able to move and develop the IM market at its own pace, due to its widespread use within the United States.',
#   'Unlike larger vehicles, you are probably already familiar with driving your car and know its limitations.',
#   'MRI is based on a physics phenomenon called nuclear magnetic resonance (NMR), which was discovered in the 1930s by Felix Bloch (working at Stanford University) and Edward Purcell (from Harvard University).',
#   'The Dominican Republic (Spanish: República Dominicana) is a Caribbean country that occupies the eastern half of the island of Hispaniola, which it shares with Haiti',
#   'Some of the rocks, which are very rare on Earth, are being sold from US$11,000 to $22,500 per ounce, which is about ten times more than the cost of gold.',
#   "The protest started around 11:00 local time (UTC+1) on Whitehall opposite the police-guarded entrance to Downing Street, the Prime Minister's official residence.",
#   'To finish, Turkish dance group Fire of Anatolia performed the show "Troy".',
#   'There were protests worldwide, several criminal prosecutions, and the leaders of the governments of Iceland and Pakistan both resigned.',
#   'Canyoning (or: canyoneering) is about going in a bottom of a canyon, which is either dry or full of water.',
#   'Income tax is structured differently in different countries, and the tax rates and brackets vary widely from one country to another.',
#   'He graduated from the College of Arts & Sciences of the University of Virginia in 1950 and was a significant donor to that institution.',
#   'A cell is the smallest structural and functional unit of a living (things) organism.',
#   'These hotels were where the rich and the famous of the day would stay, and often had fine dining and nightlife.',
#   'Out of the approximately 24,000 known meteorites to have fallen to Earth, only about 34 have been verified to be martian in origin.',
#   'The 100-metre ship was en route to pick up its usual fertiliser cargo and initially officials feared the vessel could spill a load.',
#   'I expect to return to all my duties on Monday," Arias said in a statement.',
#   'They called themselves the Moriori there were a few skirmishes and in the end, the Moriori were wiped out',
#   'Of course a first-class half-miler, a man who can beat two minutes, must be possessed of a fair amount of speed, but endurance must be cultivated at all hazards.',
#   'First, the switch for the light fixture needs to be turned off or the cable disconnected.',
#   'If you visit Greenland during cold seasons (considering that the further north you go, the colder it will be), it is essential to bring warm enough clothing.',
#   'Time has been studied by religious, philosophical, and scientific scholars for thousands of years.',
#   'Dump trucks were used to block tube entrances and assistance of 80 police were on hand to direct motorists to detours.',
#   'Antarctica is the coldest place on Earth, and surrounds the South Pole.',
#   "Unfortunately, when you make a DVD, it's borders will most likely be cut too, and if the video had subtitles too close to the bottom, they won't be fully shown.",
#   'Stearns is investigating whether taxes are used to fund abortions through Planned Parenthood in his role as chairman of the Oversight and Investigations Subcommittee, which is under the umbrella of the House Energy and Commerce Committee.',
#   'Middle distance running is a relatively inexpensive sport; however, there are many misconceptions regarding the few pieces of equipment required to participate.',
#   'British newspaper The Guardian suggested Deutsche Bank controlled roughly a third of the 1200 shell companies used to accomplish this.',
#   'Turkish Airlines flies to 39 destinations in 30 African countries as of 2014.',
#   'Occasional specialist air tours go inland, for mountaineering or to reach the Pole, which has a large base.',
#   "If just taking a photo of something isn't allowed, then you shouldn't even think of recording a video of it.",
#   'So if you were standing by the shoreline, you would be able to see down to whatever pebbles or gunk that was on the bottom.',
#   "maybe you'll discover a simple beverage that you can make for breakfast when you're back to your daily routine.",
#   'San Francisco has developed a large tourist infrastructure with numerous hotels, restaurants, and top-notch convention facilities.',
#   'Alexander, as king, offered to pay to rebuild the temple, but his offer was denied. Later, after Alexander died, the temple was rebuilt in 323 BCE.',
#   'The world has over 5,000 different languages, including more than twenty with 50 million or more speakers.',
#   "Italy's main goals were African countries. To capture those countries, they would need to have a troop launching pad, so as troops could sail across the Mediterranean Sea and invade Africa.",
#   "Basically you'll be putting up notices offering your help, pacing the docks, approaching people cleaning their yachts, trying to make contact with sailors in the bar, etc.",
#   'Avalanches are not an abnormality; steep slopes can hold only so much slow, and the excess volumes will come down as avalanches.',
#   'A visit to the site can be conveniently combined with a boat trip to the lake.',
#   'The commissioner said, "We haven\'t yet agreed on rules of origin and tariff con[c]essions, but the framework we have is enough to start trading on July 1, 2020".',
#   'Turkish diva Sezen Aksu performed with the Italian tenor Alessandro Safina and Greek singer Haris Alexiou.',
#   'When the capsule gets to Earth and enters the atmosphere, at about 5am (eastern time), it is expected to put on quite a light show for folks in Northern California, Oregon, Nevada, and Utah.',
#   'The Icelandic Meteorological Office also reported no earthquake activity in the Hekla area in the past 48 hours.',
#   "Al Gore and General Tommy Franks casually rattle off their favorite headlines (Gore's was when The Onion reported he and Tipper were having the best sex of their lives after his 2000 Electoral College defeat).",
#   'The tourist season for the hill stations generally peaks during the Indian summer.',
#   "Tours are cheaper for larger groups, so if you're by yourself or with just one friend, try to meet other people and form a group of four to six for a better per-person rate.",
#   'For a few pennies some children will tell you the story.',
#   'Just after 11:00, protesters blocked traffic on the northbound carriage in Whitehall.',
#   'Music is often recorded using sophisticated computers to process and mix sounds together.',
#   'Ten years later, he led the Soviet part of the Apollo–Soyuz mission symbolizing that the Space Race was over.',
#   'The easiest way to get started in the business of travel writing is to hone your skills on an established travel blog website.',
#   'In 2010, while nationalised, the current high street bank Northern Rock plc was split from the ‘bad bank’, Northern Rock (Asset Management).',
#   'Both golf and rugby are set to return to the Olympic Games.',
#   "The band canceled the show at Maui's War Memorial Stadium, which was set to be attended by 9,000 people, and apologized to fans.",
#   'However, they have a different kind of beauty and charm during winter, with many hill stations receiving healthy amounts of snow and offering activities such as skiing and snowboarding.',
#   'In developed countries today, providing deluxe bed and breakfasts has been raised to a sort of art-form.',
#   'The Twin Otter had been trying to land at Kokoda yesterday as Airlines PNG Flight CG4684, but had aborted once already.',
#   'This is the first time a conviction has been gained using the legislation enacted in 2003 to curb bulk e-mail, aka spam, from unsolicited distribution into users mailboxes.',
#   'Scientists call this process "stimulated emission of radiation" because the atoms are stimulated by the bright light, causing the emission of a photon of light, and light is a type of radiation.',
#   'Cell comes from the Latin word cella which means small room.',
#   'The crash site was located today and is so inaccessable that two policemen were dropped into the jungle in order to hike to the scene and seek survivors.',
#   'Sometimes the same flight can have vastly differing prices at various agregators and it pays to compare search results and to also look at the website of the airline itself before booking.',
#   "If you live in a city with a varied drinking culture, go to bars or pubs in neighborhoods you don't frequent.",
#   'Born in the Croatian capital, Zagreb, Bobek gained fame while playing for Partizan Belgrade.',
#   'Such success stories lessened the fears of change, while creating positive inclinations toward change in the future.',
#   'Most of the items buried with Tutankhamun have been well preserved, including thousands of artefacts made from precious metals and rare stones.',
#   'Thanks to undersea fiber optic cable links to Europe and broadband satellite, Greenland is well connected with 93% of the population having internet access.',
#   'Getting into your own car and heading off on a long road trip has an intrinsic appeal in its simplicity.',
#   'Its a very complex entity which consists, according to a simplified Bohr model, of a central nucleus orbited by electrons, somewhat similar to planets orbiting the sun - see Figure 1.1.',
#   'This is becoming less of an issue as lens manufacturers achieve higher standards in lens production.',
#   'You are guaranteed to get wet if you cross the bridge or walk along the trails winding near the Falls.',
#   "Many of their writers have gone on to wield great influence on Jon Stewart and Stephen Colbert's news parody shows.",
#   "When you're on a staycation, you have the time to treat yourself and take a few extra minutes to brew up something special.",
#   'Each of these nomadic rampages or marches lasts for approximately 17 days.',
#   'In some federal countries, such as the United States and Canada, income tax is levied both at the federal level and at the local level, so the rates and brackets can vary from region to region.',
#   'This authentic community is located in Howe Sound just off Vancouver, and is easily accessed via scheduled water taxis departing Granville Island in downtown Vancouver.',
#   'The use of the Internet and the World Wide Web allows learners to have access to information at all times.',
#   'The postmodern approach to learning offers the freedom from absolutes. There is no one good way to learn.',
#   'Following seabed mapping the wreck was found using an ROV.',
#   'During the last three decades, despite officially remaining a communist state, China has developed a market economy.',
#   'The player who takes the fewest strokes, or swings of the club, to complete the course wins.',
#   'Passengers were given water as they waited in 90(F)-degree heat.',
#   "However, this shouldn't really be off your concern, because often tourists are shuffled around to fill the cars.",
#   'The Northern Rock bank had been nationalised in 2008 following the revelation that the company had received emergency support from the UK Government.',
#   'Doctors began to be recruited by Emperor Augustus and even formed the first Roman Medical Corps for use in the aftermath of battles.',
#   'In the nomadic phase, army ants march at night and stop to camp during the day.',
#   'In 1957 Luxembourg became a founding member of the organization which is today known as the European Union.',
#   "Flying a drone near an airport or over a crowd is almost always a bad idea, even if it's not illegal in your area.",
#   'Using GPS navigation apps on your smartphone can be the easiest and most convenient way to navigate when out of your home country.',
#   'Red tide is caused by a higher than normal concentration of Karenia brevis, a naturally-occurring single-celled marine organism.',
#   'He received the "Hero of the Soviet Union", the Soviet Union\'s highest honor, for his work.',
#   'Vision, or the ability to see depends on visual system sensory organs or eyes.',
#   "A triceratops' teeth would have been able to crush not only leaves but even very tough branches and roots.",
#   'An additional 300 brings the total to 1,300 carriages to be acquired to relieve overcrowding.',
#   'Animals are found all over the earth. They dig in the ground, swim in the oceans, and fly in the sky.',
#   'That means we are able to successfully predict what other humans perceive, intend, believe, know or desire.',
#   'That means everything has to be put back," said researcher at the Rift Valley Research Service in Ethiopia and a co-author of the study, Berhane Asfaw.',
#   'Tornadoes strike a small area compared to other violent storms, but they can destroy everything in their path.',
#   'With the change from the quarter to the half mile run, speed becomes of much less importance and endurance becomes an absolute necessity.',
#   'The 30-year-old husband, who was born in Buffalo, was one of the four killed in the shooting, but his wife was not hurt.',
#   'The game is based on the Second Battle of Fallujah, a vicious battle between American and Iraqi forces.',
#   'The different constructions have different capabilities, are sensitive to different wave-lengths and have differing degrees of acuity, also they require different processing to make sense of the input and different numbers to work optimally.',
#   'If you look at living things under a microscope, you will see that they are made of small squares or balls.',
#   'However, new evidence suggests that the Moriori were a group of mainland Maori who migrated from New Zealand to the Chatham Islands, developing their own distinctive, peaceful culture.',
#   'However, a source with knowledge of the investigation told the Minneapolis Star-Tribune that it was Louis Jourdain, 16-year old son of Red Lake Tribal Chairman Floyd Jourdain.',
#   'Any camping below the rim in Grand Canyon requires a backcountry permit.',
#   "Mr Reid managed to drive the New Zealand's A1GP car, Black Beauty at speeds over 160km/h seven times over the bridge.",
#   'There are a limited number permits reserved for walk-in requests available on a first come, first served basis.',
#   'The next picture shows the atoms emitting photons. Of course, in reality photons are a lot smaller than those in the picture.',
#   'European Turkey (eastern Thrace or Rumelia in the Balkan peninsula) includes 3% of the country.',
#   'An official with the gas company was reporting to the scene after a neighbor called about a gas leak.',
#   "In London, about 200 people protested outside some major copyright holders' offices.",
#   'Dark clouds unrelated to any volcanic activity were reported at the base of the mountain.',
#   'Bird flu, or more formally avian influenza, can infect both birds and mammals.',
#   'There is a surcharge for having more than 2 passengers, so this option might be more expensive than necessary.',
#   'At exactly 8:46 a.m. a hush fell across the city, marking the exact moment the first jet struck its target.',
#   'The Cook Islands are an island country in free association with New Zealand, located in Polynesia, in the middle of the South Pacific Ocean.',
#   'At a minimum, you need footwear with suitable soles. Summer shoes are usually very slippery on ice and snow, even some winter boots are deficient.',
#   'Last week, Naked News announced that it would dramatically increase its international language mandate to news reporting, with three new broadcasts.',
#   'Some studies suggest that the disease must become less lethal before it can cause a global epidemic, he noted.',
#   'The pit is either heated with hot stones from a fire, or in some places geothermal heat makes areas of ground naturally hot.',
#   'The nucleus consists of two particles - neutrons and protons.',
#   'In 1977, Dr. Damadian completed the construction of the first “whole-body” MRI scanner, which he called the ”Indomitable”.',
#   'The Angkor Pass is needed to enter the temple so do not forget to bring your passport along when heading to Tonle Sap.',
#   'The walls and roofs of ice caves can collapse and cracks can get closed.',
#   'The game publisher Konami stated today in a Japanese newspaper that they will not be releasing the game Six Days in Fallujah.',
#   'Fred is the strongest tropical cyclone ever recorded so far south and east in the Atlantic since the advent of satellite imagery, and only the third major hurricane on record east of 35°W.',
#   'Sikhs call their religion Gurmat, which is Punjabi for "way of the guru". The guru is a fundamental aspect of all Indian religions but in Sikhism has taken on an importance that forms the core of Sikh beliefs.',
#   'Animal Liberation and the Royal Society for the Prevention of Cruelty to Animals (RSPCA) are again calling for the mandatory installation of CCTV cameras in all Australian abattoirs.',
#   "There were no heavy traffic delays reported on the beltway, the city's alternate route.",
#   'This is believed to be the fifth time in history that people have observed what turned out to be chemically confirmed martian material falling to Earth.',
#   'Fill your home with a rich coffee in the morning and some relaxing chamomile tea at night.',
#   'The storm, situated about 645 miles (1040 km) west of the Cape Verde islands, is likely to dissipate before threatening any land areas, forecasters say.',
#   'Japanese judoka Hitoshi Saito, winner of two Olympic gold medals, has died at the age of 54.',
#   'Traditionally, the heir to the throne would go straight into the military after finishing school.',
#   'Some cross country running during the winter, combined with gymnasium work for the upper part of the body, is the best preparation for the running season.',
#   "On September 24, 1759, Arthur Guinness signed a 9,000 year lease for the St James' Gate Brewery in Dublin, Ireland.",
#   'As the storm is far from landfall, it remains difficult to assess potential impact to the United States or Caribbean.',
#   'On October 7 an engine separated on takeoff, without injuries. Russia briefly grounded Il-76s after that accident.',
#   'Several places in Rotorua offer geothermal hangi, while other hangi can be sampled in Christchurch, Wellington and elsewhere.',
#   'The JAS 39C Gripen crashed onto a runway at around 9:30 am local time (0230 UTC) and exploded, closing the airport to commercial flights.',
#   'About ten minutes before it was due to land from its second approach it disapeared.',
#   'The company hopes to diversify its profit sources and gain popularity in areas where Skype holds a strong position, such as China, Eastern Europe, and Brazil.',
#   'Scientists at the National Hurricane Center predict that Danielle will strengthen to a hurricane by Wednesday.',
#   "If you're feeling more adventurous, take the opportunity to juice or blend up some smoothies:",
#   'While they are usually privately owned, they sometimes accommodate visiting heads of state and other dignitaries.',
#   'It is an archipelago with 15 islands spread out over 2.2 million km2 of ocean.',
#   'Its frequent portrayal in music, films, literature and popular culture has helped make the city and its landmarks known throughout the world.',
#   'The capsule will be traveling at about 12.8 km or 8 miles per second, fast enough to go from San Francisco to Los Angeles in one minute.',
#   'The modern sport of fencing is played at many levels, from students learning at a university to professional and Olympic competition.',
#   'However, the first true telescopes were made in Europe in the late 16th century.',
#   'The human hand is shorter than the foot, with straighter phalanges.',
#   'Although in the end, Krushchev sent in tanks to restore order, he did give way to some economic demands and agreed to appoint the popular Wladyslaw Gomulka as the new prime minister.',
#   'As mentioned above, though the word "Eskimo" remains acceptable in the United States, it is considered pejorative by many non-U.S. Arctic peoples, especially in Canada.',
#   'If using a drone, check well in advance as to what you are allowed to film and what permits or additional licensing are required.',
#   'Water is another example. The compound water is made up of two hydrogen atoms and one oxygen atom.',
#   'Now for Japan. Japan was an island country, just like Britain.',
#   'But, if this ever does happen probably won\'t happen for a very long time. The stars are so spread out that there are trillions of miles between stars that are "neighbors".',
#   'Born in Hong Kong, Ma studied at New York University and Harvard Law School and once held an American permanent resident "green card".',
#   'Heels should be low and wide. Sand, gravel or salt (calcium chloride) is often scattered on roads or paths to improve traction.',
#   'Evidence thereafter indicated test papers were tampered with Hall, along with 34 other education officials, was indicted in 2013.',
#   'They do this by emitting a tiny particle of light called a "photon".',
#   'For those who enjoy outdoor activities, a trek up the Sea to Sky corridor is essential.',
#   'Space for the most popular areas, such as the Bright Angel Campground adjacent to Phantom Ranch, generally fill up by the requests received on first date they are opened to reservations.',
#   "Many people dream of the day when humans can travel to another star and explore other worlds, some people wonder what's out there some belive that aliens or other life may live on another plant.",
#   'The approach to obtaining information was different. No longer did pressure reside within individual recall, but the ability to recall text became more of a focus.',
#   'Surface tension happens because the water molecules at the surface of the water are strongly attracted to each other more than they are to the air molecules above them.',
#   'Stardust will set a new all-time record for being the fastest spacecraft to return to Earth, breaking the previous record set in May of 1969 during the return of the Apollo X command module.',
#   "There's a tiny cave near the top that must be passed through, it is quite low and a rather tight squeeze.",
#   'Cells are so basic and critical to the study of life, in fact, that they are often referred to as "the building blocks of life".',
#   'The jail became notorious after prisoner abuse was discovered there after US forces took over.',
#   'In the heat of the day, travelers can experience mirages that give the illusion of water (or other things).'],
#  'spa_Latn': ['En las notas utilizaba palabras que algunos padres creían que eran groseras y, de acuerdo a los informes, utilizó además malas palabras durante la clase.',
#   'Las caminatas diurnas involucran distancias de menos de una milla hasta recorridos más extensos, que pueden cubrirse en un día.',
#   'La ciudad se ubica junto a las cataratas, que son su principal atractivo, pero este conocido destino turístico también ofrece, tanto a aventureros como a viajeros, un gran número de opciones para una estancia de mayor duración.',
#   'Tampoco se requiere que obtenga un número local del lugar en donde vive; puede recurrir a una conexión a Internet por satélite en las zonas salvajes de Chicken, en Alaska, y elegir un número que señale que usted se localiza en la soleada Arizona.',
#   'Aunque su estado físico puede variar, el químico se mantiene.',
#   'Ello le asegurará que sus preferencias o limitaciones personales coincidan con la embarcación que mejor se adecúe a ellas.',
#   'El llamado castillo de Kirby Muxloe no es tal cosa, sino, antes bien, una casa fortificada, algo típico de esa época.',
#   'El primer libro del que se tiene conocimiento fue redactado en sánscrito. Después de la compilación de Upanishads, este idioma sencillamente desapareció, por cuestiones de jerarquía.',
#   'La noche del 9 de agosto, el ojo de Morakot quedó a cerca de 60 km de distancia de la ciudad china de Fujian.',
#   'Nadia nació por cesárea el 17 de septiembre de 2007 en una maternidad de Aleisk, Rusia, con un exorbitante peso de 17 libras y 1 onza.',
#   'Presenta la misma estructura molecular, sea en estado líquido, sólido o gaseoso.',
#   'Más de un viajero estable y capaz se ha visto superado por las novedades que involucran los viajes a países en vías de desarrollo, donde muchos pequeños ajustes culturales pueden acumularse con rapidez.',
#   '«Por lo que sabemos hasta ahora, solo hay un planeta que presenta más dinamismo que Titán; se le llama Tierra», agregó Stofan.',
#   'En veinte años, el PIB de China podría ser más alto que el de los Estados Unidos.',
#   'El Océano Ártico está ligado al Mar Báltico a través del Canal del Mar Blanco-Báltico, por medio de los lagos Onega y Ladoga y a San Petersburgo, mayormente por ríos y lagos.',
#   'Jardín de la Unión. Este lugar se construyó como atrio para un convento del siglo XVII, del cual solo se conserva el edificio del Templo de San Diego.',
#   'Debido a que comparte la misma zona horaria que Hawái, a veces estas islas son denominadas «Hawái abajo del todo».',
#   'Esto se contrapone con los informes previos, que indicaban que la cancelación de la segunda vuelta habría sido inconstitucional.',
#   'Actualmente, los viajes en avión rara vez se reservan directamente con la aerolínea, sin antes realizar una búsqueda y comparación de precios.',
#   'Esto puede hacerse en un automóvil común con un cauteloso planeamiento, pero lo más recomendable es hacerlo en una 4x4; además, hay muchos lugares a los que solo se puede acceder con una 4x4 con amplia distancia entre ejes.',
#   'Los sijs tienen la convicción de que su credo constituye una religión desligada del hinduismo, pero reconocen sus orígenes y tradiciones hindúes.',
#   'Jarque participaba en un entrenamiento de pretemporada en Coverciano, Italia, temprano en la mañana. Se hospedaba en el hotel del equipo, antes de un encuentro programado para el domingo contra Bolonia.',
#   '¿Qué es una célula? Este término deriva del latín cella, que significa «cuarto de tamaño reducido», y fue empleado por primera vez por un microscopista mientras estudiaba la estructura del corcho.',
#   'En 1945 se les unió y permaneció allí hasta 1958.',
#   'En época de precipitaciones (de noviembre a marzo), el caudal de agua crecerá y las cataratas serán más impresionantes.',
#   'El proceso legal fue llevado a cabo en Virginia, ya que allí se encuentra la sede de la compañía más importante de servicios de Internet, AOL, que fue quien presentó los cargos.',
#   'Lodin también comentó que los funcionarios optaron por cancelar la segunda vuelta para que los afganos ahorraran el costo y el riesgo de seguridad de una nueva ronda.',
#   'El tiempo es algo presente en todo lugar y que tiene efectos en todas nuestras acciones; sin embargo, es difícil comprenderlo.',
#   'Hasta el momento, AOL ha logrado desarrollar y manejar el mercado de mensajería instantánea a conveniencia, gracias a su uso generalizado en EE. UU.',
#   'A diferencia de lo que ocurre con automóviles de mayor porte, es probable que usted ya se encuentre familiarizado con la conducción de su rodado y esté al tanto de sus limitaciones.',
#   'La IRM se basa en un fenómeno físico denominado resonancia magnética nuclear (RMN), cuyo descubrimiento tuvo lugar en la década de 1930, de la mano de Felix Bloch (que trabajaba para la Universidad de Stanford) y Edward Purcell (de la Universidad de Harvard).',
#   'República Dominicana es un país del Caribe que ocupa la mitad oriental de la isla La Española, la cual comparte con Haití.',
#   'Algunas de las rocas, muy poco comunes en la Tierra, se venden entre $11 000 y $22 500 dólares por onza, que representa aproximadamente diez veces el precio del oro.',
#   'La manifestación inició cerca de las 11:00 hora local (UTC +1) en Whitehall, frente a la puerta de acceso a Downing Street, residencia oficial del primer ministro, la cual contaba con vigilancia policial.',
#   'Para terminar, el grupo de danza turco Anatolia interpretó «Troya».',
#   'Se llevaron a cabo manifestaciones a nivel mundial, se condujeron numerosos juicios criminales, y los jefes de estado tanto de Islandia como de Pakistán renunciaron.',
#   'El barranquismo consiste en ir hasta el fondo de un cañón que esté seco o lleno de agua.',
#   'El impuesto sobre la renta está organizado de forma diferente en los distintos estados y las tasas impositivas y las categorías difieren mucho entre países.',
#   'Obtuvo su diploma en 1950, en la Facultad de Artes y Ciencias de la Universidad de Virginia. También realizó grandes contribuciones en su favor.',
#   'Se define a la célula como la más pequeña unidad estructural y funcional que forma un organismo (cosas) vivo.',
#   'En estos hoteles se hospedaban los ricos y famosos del momento y, con frecuencia, disfrutaban de buenas cenas y vida nocturna.',
#   'De los cerca de 24 000 meteoritos que se sabe han impactado sobre la Tierra, se ha corroborado que tan solo 34 son de provienen de Marte.',
#   'El barco de 100 metros se dirigía a recoger su carga habitual de fertilizantes y, en un comienzo, había preocupación entre los funcionarios de que alguna carga pudiera derramarse.',
#   '«Espero poder volver a mis funciones el lunes», manifestó Arias en un comunicado.',
#   'Se nombraron a sí mismos Moriori, luego hubo algunas peleas y, finalmente, fueron eliminados.',
#   'Desde ya, un corredor de la media milla de primera categoría, que puede superar los dos minutos, debe tener un buen nivel de velocidad, pero debe cultivar la resistencia a toda costa.',
#   'Lo primero que se debe hacer con la lámpara es apagar su interruptor o desconectarla.',
#   'Si visita Groenlandia en las estaciones frías (considerando que cuanto más vaya hacia el norte, menor será la temperatura), es crucial llevarse ropa bastante abrigadora.',
#   'Tanto los eruditos religiosos, como los filosóficos y los científicos han estudiado al tiempo por miles de años.',
#   'Se bloquearon los accesos a los túneles con camiones volquete y fue necesaria la participación de 80 agentes de policía para guiar a los automovilistas hacia los desvíos.',
#   'La Antártida es el sitio de menor temperatura del planeta y rodea al Polo Sur.',
#   'Lamentablemente, al crear un DVD, es muy probable que los bordes queden recortados y, si el vídeo tiene subtítulos cerca del margen inferior, no se verán enteros.',
#   'En su rol de director del Subcomité de Supervisión e Investigación, que se encuentra bajo el paraguas del Comité de Energía y Comercio, Stearns conduce una investigación para determinar si los impuestos se usan para financiar interrupciones de embarazos a través de Paternidad Planificada.',
#   'La carrera de distancia media es un deporte relativamente económico; no obstante, existen muchos conceptos erróneos en relación con los pocos equipamientos requeridos para participar.',
#   'El periódico británico The Guardian señaló que Deutsche Bank tenía el control de cerca de la tercera parte de las 1200 compañías fantasma que se usaron para llevar esto a cabo.',
#   'Desde el año 2014, Turkish Airlines tiene vuelos a 39 destinos en 30 países de África.',
#   'De vez en cuando, se llevan a cabo excursiones aéreas especializadas que se adentran para practicar montañismo o dirigirse hasta el Polo, en donde hay una base grande.',
#   'Si no se permite tomar una fotografía de algo, entonces ni siquiera debería pensar en filmarlo.',
#   'Por lo tanto, si estuviera de pie junto a la orilla, podría observar cualquier pequeña piedra o porquería que hubiese en el fondo.',
#   'Tal vez encuentre una bebida para el desayuno fácil de preparar para cuando regrese a su rutina diaria.',
#   'Con una gran variedad de hoteles, restaurantes e instalaciones para convenciones de primer nivel, San Francisco ha ido desarrollando una gran infraestructura turística.',
#   'Alejandro, como rey, ofreció costear la reconstrucción del templo, pero rechazaron su propuesta. Más adelante, después de su muerte, el templo fue reconstruido en 323 a. C.',
#   'En todo el planeta, existen más de 5000 idiomas distintos, entre los cuales más de veinte son hablados por 50 millones de personas, o más.',
#   'Italia tenía como objetivo primordial a los países africanos. Para capturarlos, precisaría una plataforma de lanzamiento de tropas para que estas pudieran navegar por el Mar Mediterráneo y, así, invadir África.',
#   'Su tarea será, básicamente, colocar avisos en los que ofrezca su ayuda, recorrer los muelles, acercarse a las personas que limpian los yates, intentar hacer contacto con los marineros en el bar, etc.',
#   'Las avalanchas no son algo anormal; las pendientes pronunciadas únicamente resisten cierta cantidad de nieve, por lo que el exceso caerá en forma de aludes.',
#   'Puede organizarse una provechosa combinación entre una visita al lugar y un paseo en barco hacia el lago.',
#   'El comisario expresó: «Si bien todavía no hemos definido las reglas de origen ni las condiciones arancelarias, el marco con el que contamos es suficiente para dar inicio a las transacciones desde el 1 de julio de 2020».',
#   'La diva turca Sezen Aksu cantó con Alessandro Safina, un tenor italiano, y con la cantante griega Haris Alexiou.',
#   'Se espera que, al momento del ingreso a la atmósfera de la cápsula, cuando esta llegue a la Tierra, lo que ocurrirá cerca de las 5 de la mañana (hora del este), produzca un espectáculo de muchas luces visible para las personas del norte de California, Oregón, Nevada y Utah.',
#   'Tampoco la Oficina Meteorológica de Islandia reportó actividad sísmica en Hekla durante las pasadas 48 horas.',
#   'Al Gore y el general Tommy Franks comentan rápidamente y de forma casual sus titulares preferidos (el de Gore fue cuando The Onion dijo que él y Tipper habían tenido el mejor sexo de sus vidas luego de ser vencidos en el Colegio Electoral del 2000).',
#   'En las estaciones de montaña de la India, la temporada alta de turistas, por lo habitual, llega a su punto más alto durante el verano.',
#   'Las excursiones son más económicas para grupos de más personas, así que, si está solo o con un único amigo, procure conocer gente y formar un grupo de cuatro a seis para obtener una mejor tarifa por cada uno.',
#   'Algunos niños relatarán una historia a cambio de una pequeña propina.',
#   'Apenas pasadas las 11:00 h, los integrantes de la manifestación bloquearon la circulación del carril de Whitehall que va hacia el norte.',
#   'Con frecuencia, la grabación de música se hace con computadoras sofisticadas a fin de procesar y mezclar sonidos.',
#   'Diez años después, estuvo al mando de la participación soviética en la misión Apollo-Soyuz, que simbolizaba el fin de la Carrera Espacial.',
#   'La manera más sencilla de comenzar en el negocio de la escritura sobre viajes es mejorar sus aptitudes en una página web de blogs de viajes establecida.',
#   'En 2010, cuando ya había sido nacionalizado, el hoy en día banco principal, Northern Rock plc, se separó del «banco malo», Northern Rock (Gestión de Activos).',
#   'El golf y el rugby están preparados para volver a las Olimpiadas.',
#   'El grupo canceló la función en el War Memorial Stadium de Maui, al que asistirían 9000 personas, y ofreció una disculpa a sus seguidores.',
#   'De todas formas, su belleza y encanto en época invernal son especiales, con un gran número de estaciones de montaña en las que nieva en cantidades provechosas, posibilitando la práctica de deportes como el esquí y tabla nieve.',
#   'En la actualidad, brindar hospedaje y desayuno de lujo se ha vuelto, para los países del primer mundo, en una clase de forma de arte.',
#   'Ayer, el Twin Otter había realizado intentos de aterrizaje en Kokoda, como vuelo CG4684 de la aerolínea PNG, pero ya había abortado una vez.',
#   'Esta es la primera vez que se obtiene una condena basada en la legislación sancionada en 2003 para detener los correos electrónicos masivos, conocidos como spam, provenientes de la distribución no solicitada en las casillas de correo de los usuarios.',
#   'Los expertos denominan a este proceso «emisión estimulada de radiación», ya que la luz brillante estimula a los átomos, lo que genera la emisión de un fotón de luz, que es un tipo de radiación.',
#   'El término célula deriva de la palabra latina cella, que quiere decir «cuarto pequeño».',
#   'Hoy se localizó el lugar del accidente y dada su inaccesibilidad, fue preciso bajar a dos policías a la jungla para que pudieran llegar a pie hasta el lugar en busca de sobrevivientes.',
#   'A veces, un mismo vuelo puede costar precios muy diferentes en varios recopiladores de contenidos, por lo que vale la pena comparar los resultados de búsqueda y navegar en el sitio web de la empresa antes de realizar la reserva.',
#   'Si usted vive en una ciudad con una cultura variada de bebidas, visite bares o pubs en vecindarios a los que no suela ir.',
#   'Bobek, oriundo de Zagreb, capital de Croacia, ganó popularidad cuando se unió al Partizan de Belgrado.',
#   'Estas historias de éxito atenuaron los temores de cambio y crearon inclinaciones positivas para el cambio en el futuro.',
#   'La mayor parte de los objetos que fueron enterrados con Tutankamón se han conservado en buen estado, entre ellos, miles de artefactos elaborados con metales preciosos y piedras exóticas.',
#   'Las conexiones de cable de fibra óptica submarinos que llegan hasta Europa y el satélite de banda ancha hacen posible que Groenlandia cuente con buena conectividad y que el 93% de la población tenga acceso a Internet.',
#   'Entrar en su propio vehículo y dar inicio a un extenso viaje por tierra tiene un atractivo intrínseco en su simpleza.',
#   'Es una estructura muy compleja que está formada, conforme el modelo simplificado de Bohr, por un núcleo central en torno al que orbitan electrones; algo similar a los planetas que giran alrededor del Sol. Ver Figura 1.1.',
#   'Este problema cada vez es menos importante gracias a que los fabricantes de lentes logran estándares más altos en su producción.',
#   'No dude que terminará mojado si atraviesa el puente o recorre los senderos sinuosos próximos a las cataratas.',
#   'Muchos de esos escritores influyeron en gran medida en los noticiarios de parodia de Jon Stewart y Stephen Colbert.',
#   'Cuando usted se encuentra de vacaciones en su casa, cuenta con el tiempo necesario para darse un gusto y dedicar unos minutos más para cocinar un plato especial.',
#   'Cada uno de estos desmadres o marchas errantes dura aproximadamente 17 días.',
#   'Existen estados federales, como Estados Unidos y Canadá, en donde el impuesto a la renta rige tanto a nivel federal como local. Como consecuencia, las tasas y categorías pueden ser distintas según la región.',
#   'En Howe Sound, exactamente junto a Vancouver, se encuentra esta auténtica comunidad a la que se puede llegar fácilmente en taxis acuáticos programados que parten desde Granville Island, en el centro de Vancouver.',
#   'El uso de Internet y de la red informática mundial permite que los estudiantes tengan acceso a la información en todo momento.',
#   'El enfoque posmodernista del aprendizaje conlleva la liberación de los absolutos; no existe solo una forma correcta de aprender.',
#   'A través del seguimiento de un mapeo del fondo marino, se encontró el naufragio con el uso de un ROV.',
#   'En las últimas tres décadas, China ha desarrollado una economía de mercado, aun cuando, oficialmente, continúa teniendo un régimen comunista.',
#   'Gana el jugador que alcanza la menor cantidad de golpes, o golpes de palo, para terminar el recorrido.',
#   'Los pasajeros pudieron beber agua mientras esperaban a una temperatura de 90 °F.',
#   'No obstante, no debería preocuparse por esto ya que, con frecuencia, los turistas se mezclan entre sí para completar los automóviles.',
#   'La nacionalización del banco Northern Rock se produjo en 2008, luego de que se diera a conocer que el gobierno del Reino Unido le había dado a la compañía un apoyo de emergencia.',
#   'El emperador Augusto comenzó a reclutar médicos que, de hecho, formaron el primer Cuerpo Médico Romano, cuya función era intervenir después de las batallas.',
#   'Durante la etapa nómada, las hormigas guerreas avanzan por la noche y, de día, se detienen para acampar.',
#   'Luxemburgo pasó a ser, en 1957, miembro fundador de lo que hoy llamamos Unión Europea.',
#   'Aun cuando sea legal en su región, no suele ser una buena idea hacer volar un dron en las inmediaciones de un aeropuerto o por encima de una multitud.',
#   'Posiblemente, el modo más simple y conveniente de navegar estando fuera de su país es instalar aplicaciones de navegación GPS en su teléfono inteligente.',
#   'La marea roja es originada por una densidad superior a la regular de Karenia Brevis, organismo marino formado por una sola célula y que es de origen natural.',
#   'Por su labor, le fue entregada la distinción «Héroe de la Unión Soviética», el mayor honor de ese estado.',
#   'La vista, o la capacidad de ver, está a cargo de los órganos sensoriales (ojos) del sistema visual.',
#   'Con su dentadura, un triceraptops hubiese podido triturar no solo hojas, sino además ramas y raíces muy duras.',
#   'Con la adquisición de unos 300 adicionales, suman un total de 1300 la cantidad de vagones incorporados con el fin de reducir la aglomeración de personas.',
#   'Los animales pueden ser hallados en cualquier rincón del planeta: cavan en el suelo, nadan en los océanos y vuelan los cielos.',
#   'Ello implica que tenemos la capacidad de hacer predicciones acertadas respecto de las percepciones de otras personas, lo que se proponen, sus creencias, conocimientos y deseos.',
#   '«Esto quiere decir que todo debe llevarse hacia atrás», indicó Berhance Asfaw, investigador para el Servicio de Investigación del Valle del Rift en Etiopía y coautor del estudio.',
#   'Si bien las superficies que azotan los tornados son pequeñas, comparadas con otras tormentas agresivas, pueden destruir todo en su camino.',
#   'Al producirse el cambio de la carrera de un cuarto a media milla, la velocidad pierde en gran medida su importancia, mientras que la resistencia se torna absolutamente necesaria.',
#   'El cónyuge, de 30 años y oriundo de Búfalo, fue uno de los cuatro fallecidos en la balacera, pero su esposa no sufrió lesiones.',
#   'El juego se basa en la Segunda Batalla de Faluya, un enfrentamiento despiadado entre el ejército norteamericano y el iraquí.',
#   'Las distintas construcciones tienen diferentes capacidades, son susceptibles de tener distintas longitudes y grados de agudeza; también requieren un procesamiento diferenciado para dar sentido a la entrada y números disímiles para que funcionen de forma óptima.',
#   'Si examina a un ser vivo bajo un microscopio, advertirá que están compuestos por pequeños cuadrados o esferas.',
#   'Nuevas pruebas sugieren, no obstante, que los Moriori fueron un grupo de maoríes continentales que salieron de Nueva Zelanda y se dirigieron a las Islas Chatham, donde desarrollaron su distintiva cultura pacífica.',
#   'No obstante, una fuente cercana a la investigación comentó al Minneapolis Star-Tribune que era Louis Jordain, de 16 años, hijo de Floyd Jourdain, presidente de la tribu Red Lake.',
#   'Es preciso contar con un permiso de travesía para poder acampar por debajo del borde del Gran Cañón.',
#   'Reid logró conducir siete veces a través del puente y superando los 160 km/h el Belleza Negra, el automóvil A1GP de Nueva Zelanda.',
#   'Existe un cupo limitado de permisos, reservados para las solicitudes sin turno previo, que se entregan por orden de llegada.',
#   'En la imagen que sigue se ilustran átomos que emiten fotones. Claro está, estos son, en verdad, de un tamaño mucho menor que los de la imagen.',
#   'La Turquía europea (Tracia Oriental o Rumelia, en la península de los Balcanes) comprende el 3 % del país.',
#   'Un empleado de la compañía de gas se acercó al lugar, a raíz de la llamada de un vecino alertando sobre una fuga de gas.',
#   'En Londres, cerca de 200 personas se manifestaron afuera de las oficinas de algunos de los propietarios de derechos de autor más importantes.',
#   'Se registraron nubes oscuras en la base de la montaña que no guardan relación con actividad volcánica alguna.',
#   'La gripe aviar, denominada con mayor formalidad influenza aviar, puede afectar a aves y mamíferos.',
#   'Se aplica un sobrecargo si son más de dos pasajeros, por lo que esta opción podría ser más cara de lo necesario.',
#   'Exactamente a las 8:46 a. m., la ciudad se volvió silencio, marcando el preciso instante en el que el primer avión alcanzó su objetivo.',
# ...
#   'Twin Otter tiyamuyta munachkasqa Kokodapi qayna punchaw CG4684 palaq hina PNG Arlines nisqaq, ichaqa huk kuti pantasqaña.',
#   'Huk kutillaraqsi huchallinimpi wichqarunku 2003 watapi apusimi kamakusqanmanta hawaspanku manaña mana munasqay qillqakunata apachimunankunaq qullunanpaq.',
#   'Amawtakuna sutichan kay ruwayta “illaypaq Kanchiy rikurichina” sutiwan, imapaña sunqunpa akchiwan rikcharisqanrayku, kayna akchipa chulla kasqanta rikurichimun, chaynapis akchipa kanchin nisqan apachiy.',
#   'Cell rimayqa hamun cella Latina rimaymanta ninantaqmi huchuy wasicha nin.',
#   'Maykunapas ancha riqsisqa kaqkunapaq, Bright Angel Campground nisqankupa hina Phantom Ranch qatiqllanpi, yaqapas quntarikun mañakuykunawan ñawpaq pachapi chaskisqakunawan.',
#   'Achka runan musqukunkun runa ima punchawllapas huk chaskaman chayanankupaq huk kawsaykuna kaptinpas ichapas huk chaskakunapi kawsay kanman hinapas.',
#   'ima yachaypas tarinapaq karqa hukniraqmi. Matipayqa manan chullallapichu chaninchakuran, hinaqa ima yuyaymanta hapiymi, hinaqa ima ñawinchasqapas yuyariymi aswanmi allinpi qawarikurqa.',
#   'Pay nirqan: “manan kanchu allin yuyay inaqa kanmanmi waykillay ima pachapipas.',
#   'Stardustmi huk musuq record llapan chachakunamanta takyachinqa, sumaq allin pawaq kutimuyninpi kay Pachakama wanpupaq, ñawpa recordta Aymuray killapi 1969 watapi chinkachispa, mudulu Apolo x comandopa kutimuyninpi.',
#   'Huchuy machay hawachan may purinapi, aswan huchuymi hinallataq matiy maticha.',
#   'Chayqa, células nisqakunaqa chanin saphihina ñuqñupiwan kanku kawsaq yachay atipanapaq, chaykamataq sutichakun “kawsaypa imaymana sapinkuna”.',
#   'Wichqana wasi astawan riqsirachikusqa wichqasqa runakunata allquchachispanku tarikusqanmantapacha fuerzas Estadounidenses nisqakuna kamachiyta hapisqankumantapacha.',
#   'Rupay punchaw, illaqkuna yanqakunata qawarinkuman muspaspa hina yakuta hina qawarinku (hukkunatapas).']}

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME, output_hidden_states=True)
# Out:
# Some weights of XGLMModel were not initialized from the model checkpoint at facebook/xglm-564M and are newly initialized: ['model.embed_positions.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Function to obtain hidden representations
def get_hidden_representations(sentence):
    tokens = tokenizer.tokenize(sentence)
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    hidden_states = outputs.hidden_states
    return tokens, hidden_states

# Save representations to HDF5 file
def save_representations(lang, sentences):
    with h5py.File(f"{lang}_representations.hdf5", "w") as f:
        for sentence, idx in zip(sentences, random_indexes):
            tokens, hidden_states = get_hidden_representations(sentence)
            # Calculate sentence representation (mean-pooling)
            sentence_representation = torch.mean(torch.stack(hidden_states)[:, 1:-1, :], dim=0)  # Mean over all layers, exclude padding tokens
            # Save token representations
            for layer_idx, layer_output in enumerate(hidden_states):
                for token_idx, (token, token_hidden) in enumerate(zip(tokens, layer_output[1:-1])):  # Exclude CLS and SEP tokens
                    dataset_name = f"{idx}/{layer_idx}/{token_idx}_{token}"
                    f.create_dataset(dataset_name, data=token_hidden.numpy())
            # Save sentence representation
            sentence_rep_dataset_name = f"{idx}/sentence_representation"
            f.create_dataset(sentence_rep_dataset_name, data=sentence_representation.numpy())
    print(f"Representations for {lang} saved to {lang}_representations.hdf5")

# Save representations for each language
for lang in LANGUAGES:
    save_representations(lang, extracted_sentences[lang])
# Out:
# Representations for eng_Latn saved to eng_Latn_representations.hdf5
# Representations for spa_Latn saved to spa_Latn_representations.hdf5
# Representations for deu_Latn saved to deu_Latn_representations.hdf5
# Representations for arb_Arab saved to arb_Arab_representations.hdf5
# Representations for tam_Taml saved to tam_Taml_representations.hdf5
# Representations for quy_Latn saved to quy_Latn_representations.hdf5
